# %% [markdown]
# <a href="https://colab.research.google.com/github/pranjul-05/Tensors_begining/blob/main/ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LinearRegression

# %%
from sklearn.linear_model importfrom sklearn.linear_model import LinearRegression
import numpy as np

# Training data
X = np.array([[1000], [1200], [1500], [1800]])
y = np.array([200000, 240000, 300000, 360000])

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Predict price for a 1400 sq ft house
prediction = model.predict([[1400]])

print("Predicted Price:", prediction[0])
import numpy as np

# Training data
X = np.array([[1000], [1200], [1500], [1800]])
y = np.array([200000, 240000, 300000, 360000])

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Predict price for a 1400 sq ft house
prediction = model.predict([[1400]])

print("Predicted Price:", prediction[0])
